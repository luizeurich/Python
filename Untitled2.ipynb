# %% [markdown]
# <a href="https://colab.research.google.com/github/luizeurich/Python/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #aula 4 ✈  ♒   ❤

# %%
def tabuada(numero):
      for contador in range(1, 11):  # Gera números de 1 a 10
              print(f"{numero} x {contador} = {numero * contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)
# Out:
# Digite um número para ver sua tabuada: 7
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70

# %% [markdown]
# #AULA 5 ✊  🫀   🐸

# %%
def tabuada(numero):
      for contador in range(1, 11):  # Gera números de 1 a 10
              print(f"{numero} / {contador} = {numero // contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)
# Out:
# Digite um número para ver sua tabuada: 7
# 7 / 1 = 7
# 7 / 2 = 3
# 7 / 3 = 2
# 7 / 4 = 1
# 7 / 5 = 1
# 7 / 6 = 1
# 7 / 7 = 1
# 7 / 8 = 0
# 7 / 9 = 0
# 7 / 10 = 0

# %% [markdown]
# #aula 6 chatbot ♟   ⚰     ⛈

# %% [markdown]
# #aula 7 listas 👍   🐯    🎪

# %%
import random
dica = [
"Conquiste a sua semana com a energia de hoje! ✨",
"É hora de acelerar e colocar seus planos em prática! 🚀",
"Mantenha o foco, a persistência de hoje te levará ao sucesso de amanhã. 🎯",
 "Não pare agora, a satisfação do dever cumprido espera por você. 🌟",
"celebre o progresso e prepare-se para recarregar as energias. O fim de semana chegou! 🥳",
"Desacelere, respire fundo e faça algo que a sua alma está precisando🌻",
"encontre a calma no presente e visualize a semana incrível que está por vir. 🌻"
]
